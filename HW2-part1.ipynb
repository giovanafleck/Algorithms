# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statistics import mode
from statistics import median

# %% [markdown]
# # Pandas Review

# %% [markdown]
# This HW covers the concepts simple pandas concepts introduced in class using NBA Players Stats - 2014-2015 data
# To find out more about the data follow the link: https://www.kaggle.com/drgilermo/nba-players-stats-20142015/version/1

# %% [markdown]
# ## Load `players_stats.csv`

# %%
df = pd.read_csv('players_stats.csv')

# %%
df.head()
# Out:
#             Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0       AJ Price            26   324   133   51  137  37.2   15   57  26.3
# 1   Aaron Brooks            82  1885   954  344  817  42.1  121  313  38.7
# 2   Aaron Gordon            47   797   243   93  208  44.7   13   48  27.1
# 3  Adreian Payne            32   740   213   91  220  41.4    1    9  11.1
# 4     Al Horford            76  2318  1156  519  965  53.8   11   36  30.6
#
#    ...   Age  Birth_Place           Birthdate                    Collage  \
# 0  ...  29.0           us     October 7, 1986  University of Connecticut
# 1  ...  30.0           us    January 14, 1985       University of Oregon
# 2  ...  20.0           us  September 16, 1995      University of Arizona
# 3  ...  24.0           us   February 19, 1991  Michigan State University
# 4  ...  29.0           do        June 3, 1986      University of Florida
#
#    Experience  Height  Pos  Team  Weight        BMI
# 0           5   185.0   PG   PHO   81.45  23.798393
# 1           6   180.0   PG   CHI   72.45  22.361111
# 2           R   202.5   PF   ORL   99.00  24.142661
# 3           R   205.0   PF   ATL  106.65  25.377751
# 4           7   205.0    C   ATL  110.25  26.234384
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Explore the data in 3 different ways (using 3 different methods)
# Hint: you want to use methods that show the size and shape of your dataframe

# %%
df.shape
# Out:
# (490, 34)

# %%
df.dtypes
# Out:
# Name             object
# Games Played      int64
# MIN               int64
# PTS               int64
# FGM               int64
# FGA               int64
# FG%             float64
# 3PM               int64
# 3PA               int64
# 3P%             float64
# FTM               int64
# FTA               int64
# FT%             float64
# OREB              int64
# DREB              int64
# REB               int64
# AST               int64
# STL               int64
# BLK               int64
# TOV               int64
# PF                int64
# EFF               int64
# AST/TOV         float64
# STL/TOV         float64
# Age             float64
# Birth_Place      object
# Birthdate        object
# Collage          object
# Experience       object
# Height          float64
# Pos              object
# Team             object
# Weight          float64
# BMI             float64
# dtype: object

# %%
df.size
# Out:
# 16660

# %% [markdown]
# ## Introduction to Statistics
# #### Calculate the mean, mode and median of `MIN` and `PTS` fields

# %%
df.MIN.mean()
# Out:
# 1214.7142857142858

# %%
df.MIN.mode()
# Out:
# 0      23
# 1      43
# 2    2455
# dtype: int64

# %%
(median(df.MIN))
# Out:
# 1193.0

# %%
df.PTS.mean()
# Out:
# 502.10816326530613

# %%
df.PTS.mode()
# Out:
# 0    0
# dtype: int64

# %%
(median(df.PTS))
# Out:
# 423.0

# %% [markdown]
# #### From the description of the data find out what information is contained in the `MIN` and `PTS` fields

# %%
df.MIN.describe()
# Out:
# count     490.000000
# mean     1214.714286
# std       820.570132
# min         3.000000
# 25%       492.250000
# 50%      1193.000000
# 75%      1905.750000
# max      2981.000000
# Name: MIN, dtype: float64

# %%
df.PTS.describe()
# Out:
# count     490.000000
# mean      502.108163
# std       422.084232
# min         0.000000
# 25%       145.250000
# 50%       423.000000
# 75%       774.000000
# max      2217.000000
# Name: PTS, dtype: float64

# %% [markdown]
# ### Compute the average number of minutes all the players spend on the field

# %%
df.groupby(['Name']).MIN.mean().reset_index()
# Out:
#                   Name   MIN
# 0             AJ Price   324
# 1         Aaron Brooks  1885
# 2         Aaron Gordon   797
# 3        Adreian Payne   740
# 4           Al Horford  2318
# 5         Al Jefferson  1992
# 6      Al-Farouq Aminu  1366
# 7        Alan Anderson  1744
# 8           Alec Burks   899
# 9            Alex Kirk    14
# 10            Alex Len  1518
# 11        Alexey Shved   767
# 12       Alexis Ajinca   957
# 13        Allen Crabbe   683
# 14          Alonzo Gee   661
# 15   Amar'e Stoudemire  1244
# 16        Amir Johnson  1979
# 17    Anderson Varejao   636
# 18       Andre Dawkins    22
# 19      Andre Drummond  2502
# 20      Andre Iguodala  2069
# 21        Andre Miller  1253
# 22      Andre Roberson  1286
# 23     Andrea Bargnani   785
# 24    Andrei Kirilenko    36
# 25        Andrew Bogut  1583
# 26    Andrew Nicholson   492
# 27      Andrew Wiggins  2969
# 28     Anthony Bennett   894
# 29       Anthony Davis  2455
# ..                 ...   ...
# 460      Trevor Booker  1564
# 461         Trey Burke  2288
# 462   Tristan Thompson  2194
# 463       Troy Daniels   397
# 464          Ty Lawson  2665
# 465        Tyler Ennis   411
# 466   Tyler Hansbrough  1058
# 467      Tyler Johnson   603
# 468       Tyler Zeller  1731
# 469       Tyreke Evans  2690
# 470       Tyrus Thomas     7
# 471     Tyson Chandler  2286
# 472      Udonis Haslem   995
# 473        Vander Blue    74
# 474      Victor Claver    76
# 475     Victor Oladipo  2573
# 476       Vince Carter  1091
# 477    Wayne Ellington  1675
# 478     Wesley Johnson  2245
# 479    Wesley Matthews  2024
# 480        Will Barton   984
# 481         Will Bynum    67
# 482        Will Cherry    69
# 483       Willie Green   951
# 484    Wilson Chandler  2471
# 485       Xavier Henry    86
# 486        Zach LaVine  1902
# 487      Zach Randolph  2304
# 488      Zaza Pachulia  1730
# 489       Zoran Dragic    75
#
# [490 rows x 2 columns]

# %%
group_avg = df.groupby(['Name']).MIN.mean().reset_index()

# %%
group_avg.mean()
# Out:
# MIN    1214.714286
# dtype: float64

# %% [markdown]
# ### Now compute the average number of minutes each team spends on the field

# %%
df = df.dropna(subset=['Team', 'MIN'])

# %%
df.MIN.mean()
# Out:
# 1246.649289099526

# %%
team_avg = df.groupby(['Team']).MIN.mean().reset_index()

# %%
team_avg.mean()
# Out:
# MIN    1249.839526
# dtype: float64

# %% [markdown]
# ###  Why is it different? What is the right way to calculate the Average of averages?
# Please use classwork as a reference
# ### Calculate the average number of minutes all teams spend on the field

# %%
count_and_mean = df.groupby(['Team']).agg({'MIN':['mean', 'count', 'median']}).reset_index()

# %%
count_and_mean
# Out:
#    Team          MIN
#                 mean count  median
# 0   ATL  1358.466667    15  1123.0
# 1   BOS  1450.875000     8  1646.0
# 2   CHA  1321.500000    14  1451.5
# 3   CHI  1420.071429    14  1632.0
# 4   CLE  1195.583333    12   901.0
# 5   DAL  1414.666667    15  1406.0
# 6   DEN  1231.272727    11  1087.0
# 7   DET  1276.818182    11  1230.0
# 8   GSW  1432.400000    15  1468.0
# 9   HOU  1271.636364    11   889.0
# 10  IND  1376.066667    15  1267.0
# 11  LAC  1258.285714    14  1089.0
# 12  LAL  1136.937500    16  1220.0
# 13  MEM  1392.142857    14  1372.5
# 14  MIA   970.916667    12   804.0
# 15  MIL  1282.500000    12  1508.0
# 16  MIN   964.375000    16   880.0
# 17  NJN  1165.461538    13   781.0
# 18  NOH  1345.062500    16  1607.5
# 19  NYK  1197.312500    16  1233.5
# 20  OKC  1346.600000    15  1286.0
# 21  ORL  1317.000000    15   845.0
# 22  PHI   976.400000    15   540.0
# 23  PHO  1133.062500    16   864.5
# 24  POR  1374.312500    16  1191.0
# 25  SAC  1168.307692    13  1192.0
# 26  SAS  1254.062500    16  1255.0
# 27  TOR  1264.214286    14  1674.5
# 28  UTA  1071.750000    16   981.5
# 29  WAS  1127.125000    16  1244.0

# %%
sum(count_and_mean['MIN']['count']*count_and_mean['MIN']['mean'])/len(df)
# Out:
# 1246.649289099526

# %%
sum(count_and_mean['MIN']['count'])
# Out:
# 422

# %%
len(df)
# Out:
# 422

# %%
df[df.Team.isnull()==True]
# Out:
#                    Name  Games Played   MIN   PTS  FGM   FGA    FG%  3PM  3PA  \
# 15    Amar'e Stoudemire            59  1244   680  273   490   55.7    0    4
# 17     Anderson Varejao            26   636   255  111   200   55.5    0    2
# 27       Andrew Wiggins            82  2969  1387  497  1137   43.7   39  126
# 31     Anthony Tolliver            76  1433   482  161   393   41.0  106  290
# 41           Beno Udrih            79  1494   605  246   505   48.7   26   97
# 48       Brandan Wright            75  1449   544  233   363   64.2    0    3
# 68   Charlie Villanueva            64   678   403  150   362   41.4   83  221
# 80            CJ Wilcox            21   101    41   16    38   42.1    7   19
# 83          Cody Zeller            62  1487   472  172   373   46.1    1    1
# 104          David Wear             2     7     0    0     2    0.0    0    1
# 112      Deron Williams            68  2114   884  298   771   38.7   87  237
# 115    Derrick Williams            74  1462   617  217   485   44.7   49  156
# 119        Dion Waiters            80  2208   940  375   946   39.6   73  246
# 123       Dorell Wright            48   593   219   72   190   37.9   41  108
# 131         Dwyane Wade            62  1971  1331  509  1084   47.0   29  102
# 135           Ekpe Udoh            33   128    29   11    24   45.8    0    0
# 137      Elijah Millsap            47   924   248   81   238   34.0   28   90
# 138     Elliot Williams            13   119    37   14    37   37.8    8   18
# 148        Festus Ezeli            46   504   201   76   139   54.7    0    0
# 158      Gerald Wallace            32   286    35   14    34   41.2    1    3
# 160         Gigi Datome            21   209   105   43    89   48.3   18   40
# 163  Glenn Robinson III            35   261    73   26    67   38.8    5   19
